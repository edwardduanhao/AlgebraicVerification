# %%
from model import *
from nnexpansion import *

# %%
# Create a simple test
input_dim = 2
output_dim = 2
hidden_dims = [3, 3]
polynomial_degree = 2

# Initialize the network
model = PolynomialNetwork(
    input_dim=input_dim,
    output_dim=output_dim,
    hidden_dims=hidden_dims,
    polynomial_degree=polynomial_degree
)

x_test = torch.randn(5, input_dim)
y_test = model(x_test)
print("Model output:", y_test)
# Out:
# Model output: tensor([[ 0.0606, -0.0159],
#         [ 0.0583, -0.0090],
#         [ 0.0609, -0.0157],
#         [ 0.0533,  0.0026],
#         [ 0.0631, -0.0178]], grad_fn=<AddmmBackward0>)

# %%
# Monomial Expansion
monoms, C = polynomial_nn_expansion(model)
print("Number of monomials: ", len(monoms))
print("Shape of Coefficient matrix:", C.shape)
    
# Verify the expansion is correct
print("\n" + "="*50)
is_correct = verify_expansion(model, monoms, C)
print(f"Expansion verification: {'PASSED' if is_correct else 'FAILED'}")
# Out:
# Input symbols: (x0, x1)
# Layer 0 weight: (3, 2)
# Layer 0 bias: (3, 1)
# Layer 0 activation: (3,)
# Layer 1 weight: (3, 3)
# Layer 1 bias: (3, 1)
# Layer 1 activation: (3,)
# Layer 2 weight: (2, 3)
# Layer 2 bias: (2, 1)
# Layer 2 activation: None
# Polynomial expansion took 0.0902 seconds.
# Number of monomials:  15
# Shape of Coefficient matrix: (2, 15)
#
# ==================================================
# Verification Results:
# Max absolute difference: 2.45e-08
# Mean absolute difference: 7.67e-09
# Within tolerance (1e-06): True
# Expansion verification: PASSED

# %%
# Test the compute_class_differences function
print("Testing compute_class_differences function:")
print(f"Coefficient matrix shape: {C.shape}")

# Test with gold_class = 0
gold_class = 0
coeff_diff = compute_class_differences(C, gold_class)
print(f"Shape of coefficient differences: {coeff_diff.shape}")
# Out:
# Testing compute_class_differences function:
# Coefficient matrix shape: (2, 15)
# Shape of coefficient differences: (1, 15)

# %%
print(C)
print(monoms)
# Out:
# [[0.0617410419986258 -0.00195477330291478 -0.000853038948048770
#   -0.000553429043839442 -0.00433542501238877 -0.00126525267213562
#   0.000121712761163256 0.000368001915928579 0.000321105100396570
#   8.67579524423203e-5 5.72527818686367e-5 0.000236959308572738
#   0.000356529120715036 0.000209640652255786 4.30731891332162e-5]
#  [-0.0180664379767714 0.00330507650253605 0.00296445912921629
#   0.00336906058989028 0.00574510370315251 0.00259680065368826
#   -0.000114606354238367 -0.000350046587549521 -0.000305016121565860
#   -7.88594004264403e-5 -4.48140362361156e-5 -0.000216199294319814
#   -0.000337283760628349 -0.000199686953015783 -3.91263457114025e-5]]
# [(0, 0), (0, 1), (1, 0), (0, 2), (1, 1), (2, 0), (0, 3), (1, 2), (2, 1), (3, 0), (0, 4), (1, 3), (2, 2), (3, 1), (4, 0)]
